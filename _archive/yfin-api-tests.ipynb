# %%
import yfinance as yfin
import pandas as pd

# %%
training_stocks = ['NOBL', 'VYMI', 'PEY', 'XLE', 'VYM', 'HDV', 'GLNCY',
				   'DGRO', 'HDV', 'JNK', 'HYG', 'SCHD', 'IXUS', 'DJIA',
				   'LIT', 'SPHD', 'ISCF', 'HSCZ', 'HDEF', 'PCY', 'BNDX',
				   'SMX', 'HEFA', 'IYK', 'USOI', 'XLF', 'VFH', 'KRE',
				   'IYF', 'FNCL', 'QQQ', 'SPY', 'VTI', 'ITOT', 'XLK',
				   'XLY', 'XLV', 'EEM', 'VEU', 'VB']

# %%
# Does not work for ETFs only for company stocks
data = yfin.Ticker('NVDA')
data.get_recommendations(proxy=None, as_dict=False)
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         12   48     4     0           0
# 1    -1m         12   48     4     0           0
# 2    -2m         11   48     4     0           0
# 3    -3m         11   48     4     0           0

# %%
# Does not work for ETFs only for company stocks
data = yfin.Ticker('GLNCY')
data.get_upgrades_downgrades(proxy=None, as_dict=False)
# Out:
#                                  Firm     ToGrade   FromGrade Action
# GradeDate
# 2016-09-19 07:23:31     Credit Suisse  Outperform     Neutral     up
# 2016-07-18 05:45:25     Credit Suisse     Neutral  Outperform   down
# 2016-04-18 13:50:43         Citigroup     Neutral         Buy   down
# 2016-04-07 08:13:36         JP Morgan     Neutral  Overweight   down
# 2016-02-10 10:40:55  Societe Generale        Hold         Buy   down

# %%
# Not available for all stocks
data = yfin.Ticker('NVDA')
data.get_sustainability()
# Out:
#                                                                            esgScores
# adult                                                                          False
# alcoholic                                                                      False
# animalTesting                                                                  False
# catholic                                                                        None
# coal                                                                           False
# controversialWeapons                                                           False
# environmentPercentile                                                           None
# environmentScore                                                                2.73
# esgPerformance                                                              LAG_PERF
# furLeather                                                                     False
# ...

# %%
# Only available for company stocks
data = yfin.Ticker('GLNCY')
data.get_analyst_price_targets()
# Out:
# {'current': 9.14, 'low': 12.4, 'high': 12.4, 'mean': 12.4, 'median': 12.4}

# %%
# Only available for company stocks
data = yfin.Ticker('TSM')
data.get_earnings_estimate(proxy=None, as_dict=False)
# Out:
#      numberOfAnalysts      avg   low    high  yearAgoEps  growth
# 0q                  5  2.19961  2.11  2.2300     1.44000  0.5275
# +1q                 5  1.92600  1.84  2.0300     1.38000  0.3957
# 0y                  8  7.05681  6.91  7.3300     5.18000  0.3623
# +1y                 9  8.88573  8.06  9.4466     7.05681  0.2592
